# %% [markdown]
# # Ploting different new features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ta import *

# %%
# Load data
df = pd.read_csv('../data/datas.csv', sep=',')
df = utils.dropna(df)

# %%
df.shape
# Out:
# (46306, 8)

# %%
df.head()
# Out:
#      Timestamp  Open  High   Low  Close  Volume_BTC  Volume_Currency  \
# 0   1315918800  5.80  6.00  5.80   6.00   25.000000       149.190000
# 1   1315922400  5.95  5.95  5.76   5.76   22.353982       132.041023
# 2   1315926000  5.65  5.65  5.65   5.65    2.542000        14.362300
# 6   1315940400  5.92  5.97  5.92   5.97    8.475400        50.504066
# 18  1315983600  5.58  5.62  5.54   5.62   16.425700        91.537032
#
#     Weighted_Price
# 0         5.967600
# 1         5.906823
# 2         5.650000
# 6         5.958901
# 18        5.572793

# %%
# Add all ta features filling nans values
df = add_all_ta_features(df, "Open", "High", "Low", "Close", "Volume_BTC", fillna=True)

# %%
df.shape
# Out:
# (46306, 56)

# %% [markdown]
# # Ploting some volatility features

# %% [markdown]
# ### Bollinger Bands

# %%
plt.plot(df[40500:41000].Close)
plt.plot(df[40500:41000].volatility2, label='High BB')
plt.plot(df[40500:41000].volatility3, label='Low BB')
plt.plot(df[40500:41000].volatility4, label='EMA BB')
plt.title('Bollinger Bands')
plt.legend()
plt.show()

# %% [markdown]
# ### Keltner Channel

# %%
plt.plot(df[40500: 41000].Close)
plt.plot(df[40500: 41000].volatility7, label='Central KC')
plt.plot(df[40500: 41000].volatility8, label='High KC')
plt.plot(df[40500: 41000].volatility9, label='Low KC')
plt.title('Keltner Channel')
plt.legend()
plt.show()

# %% [markdown]
# ### Donchian Channel

# %%
plt.plot(df[40500: 41000].Close)
plt.plot(df[40500: 41000].volatility12, label='High DC')
plt.plot(df[40500: 41000].volatility13, label='Low DC')
plt.title('Donchian Channel')
plt.legend()
plt.show()

# %% [markdown]
# # Ploting trend features

# %% [markdown]
# ### MACD

# %%
plt.plot(df[40500:41000].trend1, label='MACD')
plt.plot(df[40500:41000].trend2, label='MACD Signal')
plt.plot(df[40500:41000].trend3, label='MACD Difference')
plt.title('MACD, MACD Signal and MACD Difference')
plt.legend()
plt.show()

# %% [markdown]
# ### KST

# %%
plt.plot(df[40700:41000].trend17, label='KST')
plt.plot(df[40700:41000].trend18, label='KST Signal')
plt.plot(df[40700:41000].trend19, label='KST - KST Signal')
plt.title('Know Sure Thing (KST)')
plt.legend()
plt.show()

# %% [markdown]
# ### Ichimoku Kinkō Hyō

# %%
plt.plot(df[40500:41000].Close)
plt.plot(df[40500:41000].trend20, label='Ichimoku a')
plt.plot(df[40500:41000].trend21, label='Ichimoku b')
plt.title('Ichimoku Kinko Hyo')
plt.legend()
plt.show()

# %% [markdown]
# # Ploting all features

# %%
for col in df.columns:
    plt.plot(df[col])
    plt.title(col)
    plt.show()
